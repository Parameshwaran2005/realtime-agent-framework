# %% [markdown]
# # Get the Banking77 dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/train.csv")

# %%
df.shape
# Out:
# (10003, 2)

# %%
df.head()
# Out:
#                                                 text      category
# 0                     I am still waiting on my card?  card_arrival
# 1  What can I do if my card still hasn't arrived ...  card_arrival
# 2  I have been waiting over a week. Is the card s...  card_arrival
# 3  Can I track my card while it is in the process...  card_arrival
# 4  How do I know if I will get my card, or if it ...  card_arrival

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10003 entries, 0 to 10002
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      10003 non-null  object
#  1   category  10003 non-null  object
# dtypes: object(2)
# memory usage: 156.4+ KB

# %%
df.isnull().sum()
# Out:
# text        0
# category    0
# dtype: int64

# %%
df.describe()
# Out:
#                                   text                  category
# count                            10003                     10003
# unique                           10003                        77
# top     I am still waiting on my card?  card_payment_fee_charged
# freq                                 1                       187

# %%
df['category'].value_counts()
# Out:
# category
# card_payment_fee_charged                            187
# direct_debit_payment_not_recognised                 182
# balance_not_updated_after_cheque_or_cash_deposit    181
# wrong_amount_of_cash_received                       180
# cash_withdrawal_charge                              177
#                                                    ...
# lost_or_stolen_card                                  82
# card_swallowed                                       61
# card_acceptance                                      59
# virtual_card_not_working                             41
# contactless_not_working                              35
# Name: count, Length: 77, dtype: int64

# %%
df['category'].nunique()
# Out:
# 77

# %%
df['text'] = df['text'].str.lower() # lowercase

# %%
df['text']= df['text'].str.strip()

# %%
df.sample(5) # random
# Out:
#                                                    text  \
# 9050  i wanted to know what discounts were offered f...
# 7247  why did you charge me a fee when i made a tran...
# 1104              when can i expect to receive my card?
# 7661  can you please explain the topping up transfer...
# 7181  why is my transfer more expensive than i thought?
#
#                     category
# 9050         exchange_charge
# 7247    transfer_fee_charged
# 1104  card_delivery_estimate
# 7661   transfer_into_account
# 7181    transfer_fee_charged

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(df['text'])

# %%
X.shape
# Out:
# (10003, 2320)

# %%
y = df['category']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# training dataset prediction

# %%
model.predict(X)
# Out:
# array(['card_arrival', 'card_arrival', 'card_arrival', ...,
#        'country_support', 'country_support', 'country_support'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score, f1_score

# %%
accuracy_score(y, model.predict(X))
# Out:
# 0.9309207237828652

# %%
f1_score(y, model.predict(X), average='macro')
# Out:
# 0.9294262328529259

# %% [markdown]
# # test dataset

# %%
test_df = pd.read_csv('../data/test.csv')

# %%
test_df['text'] = test_df['text'].str.lower()

# %%
X_test = vectorizer.transform(test_df['text'])
y_test = test_df['category']

# %%
model.predict(X_test)
# Out:
# array(['card_linking', 'card_arrival', 'card_arrival', ...,
#        'country_support', 'country_support', 'country_support'],
#       dtype=object)

# %%
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.8769480519480519

# %%
f1_score(y_test, model.predict(X_test), average='macro')
# Out:
# 0.8768846181655345

# %%
import joblib

joblib.dump(model, "model.pkl")
joblib.dump(vectorizer, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']
